# %%
# ports

pinA = "P2_18"
pinB = "P2_20"

# %%
"""
Encoder library for Raspberry Pi for measuring quadrature encoded signals.
created by Mivallion <mivallion@gmail.com>
Version 1.0 - 01 april 2020 - inital release
"""

# import RPi.GPIO as GPIO
import Adafruit_BBIO.GPIO as GPIO

class Encoder(object):
    """
    Encoder class allows to work with rotary encoder
    which connected via two pin A and B.
    Works only on interrupts because all RPi pins allow that.
    This library is a simple port of the Arduino Encoder library
    (https://github.com/PaulStoffregen/Encoder) 
    """
    def __init__(self, A, B):
        GPIO.setmode(GPIO.BCM)
        GPIO.setup(A, GPIO.IN)
        GPIO.setup(B, GPIO.IN)
        self.A = A
        self.B = B
        self.pos = 0
        self.state = 0
        if GPIO.input(A):
            self.state |= 1
        if GPIO.input(B):
            self.state |= 2
        # GPIO.add_event_detect(A, GPIO.BOTH, callback=self.__update)
        # GPIO.add_event_detect(B, GPIO.BOTH, callback=self.__update)
        GPIO.add_event_detect(A, GPIO.BOTH, callback=self.__update)
        GPIO.add_event_detect(B, GPIO.BOTH, callback=self.__update)

    """
    update() calling every time when value on A or B pins changes.
    It updates the current position based on previous and current states
    of the rotary encoder.
    """
    def __update(self, channel):
        state = self.state & 3
        if GPIO.input(self.A):
            state |= 4
        if GPIO.input(self.B):
            state |= 8

        self.state = state >> 2

        if state == 1 or state == 7 or state == 8 or state == 14:
            self.pos += 1
        elif state == 2 or state == 4 or state == 11 or state == 13:
            self.pos -= 1
        elif state == 3 or state == 12:
            self.pos += 2
        elif state == 6 or state == 9:
            self.pos -= 2


    """
    read() simply returns the current position of the rotary encoder.
    """
    def read(self):
        return self.pos

# %%
import encoder
pinA = "P2_18"
pinB = "P2_20"
e = encoder.Encoder(pinA, pinB)  
e.read()


import Adafruit_BBIO.GPIO as GPIO
def print_pressed1(self):
    print("pressed: 1\n")


def print_pressed2(self):
    print("pressed: 2\n")


pinBtn1 = "P2_22"
pinBtn2 = "P2_24"

GPIO.setup(pinBtn1, GPIO.IN)
GPIO.setup(pinBtn2, GPIO.IN)
GPIO.add_event_detect(gpio=pinBtn1, edge=GPIO.FALLING, callback=print_pressed1)
GPIO.add_event_detect(gpio=pinBtn2, edge=GPIO.FALLING, callback=print_pressed2)
# GPIO.input(pinBtn)
# GPIO.add_event_callback(gpio = pinBtn, edge = GPIO.FALLING, callback = print_pressed)
# GPIO.add_event_detect(channel=pinBtn, edge=GPIO.FALLING, callback=print_pressed)
# GPIO.add_event_detect(channel=pinBtn, gpio=pinBtn, edge=GPIO.FALLING, callback=print_pressed)
